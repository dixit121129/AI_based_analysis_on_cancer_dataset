# %%
#Im making an actual AI here.
##Hey there! in this project im using the real dataset ie,cancer dataset which the infomation regarding tumors which may or maynot be cancers.
### The AI which im making here will analyse that the tumors are malignate(it is to be removed) or benign(it is not cancerous). 
#### We gonna have the AI which will map the correlations between the features that will allow the AI to find out the tumor is malignate or benign.
import pandas as pd

# %%
#import the dataset.
dataset=pd.read_csv("cancer.csv")
dataset.head(10)
# Out:
#    diagnosis(1=m, 0=b)  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0                    1        17.99  ...          0.4601                  0.11890
# 1                    1        20.57  ...          0.2750                  0.08902
# 2                    1        19.69  ...          0.3613                  0.08758
# 3                    1        11.42  ...          0.6638                  0.17300
# 4                    1        20.29  ...          0.2364                  0.07678
# 5                    1        12.45  ...          0.3985                  0.12440
# 6                    1        18.25  ...          0.3063                  0.08368
# 7                    1        13.71  ...          0.3196                  0.11510
# 8                    1        13.00  ...          0.4378                  0.10720
# 9                    1        12.46  ...          0.4366                  0.20750
#
# [10 rows x 31 columns]

# %%
#setting the x and y attribute.
x=dataset.drop(columns=["diagnosis(1=m, 0=b)"])

# %%
y=dataset["diagnosis(1=m, 0=b)"]

# %%
#importing sklearn (Scikit-learn (Sklearn) is the most useful and robust library for machine learning in Python. It provides a selection of efficient tools for machine learning and statistical modeling including classification, regression, clustering and dimensionality reduction via a consistence interface in Python.)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2)

# %%
#building and training the model.
import tensorflow as tf

model = tf.keras.models.Sequential()

# %%
#adding layers to the model.
model.add(tf.keras.layers.Dense(256,input_shape=x_train.shape[1:],activation='sigmoid'))
model.add(tf.keras.layers.Dense(256,activation='sigmoid'))
model.add(tf.keras.layers.Dense(1,activation='sigmoid'))

# %%
#compiling the model.
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train, y_train, epochs=500)                   #epoch-iterates the algorithm on the dataset according to the value given.
# Out:
# Epoch 1/500
# 15/15 [==============================] - 1s 3ms/step - loss: 0.2060 - accuracy: 0.9253
# Epoch 2/500
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1590 - accuracy: 0.9363
# Epoch 3/500
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1743 - accuracy: 0.9385
# Epoch 4/500
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1747 - accuracy: 0.9363
# Epoch 5/500
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1409 - accuracy: 0.9407
# Epoch 6/500
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1547 - accuracy: 0.9297
# Epoch 7/500
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1589 - accuracy: 0.9341
# Epoch 8/500
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1458 - accuracy: 0.9407
# Epoch 9/500
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1416 - accuracy: 0.9429
# Epoch 10/500
# ...

# %%
#Evaluates the model.
model.evaluate(x_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1747 - accuracy: 0.9298
# [0.17468109726905823, 0.9298245906829834]
